# %%
# clone darknet repo
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15298, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 15298 (delta 1), reused 5 (delta 0), pack-reused 15289
# Receiving objects: 100% (15298/15298), 13.70 MiB | 15.86 MiB/s, done.
# Resolving deltas: 100% (10383/10383), done.

# %%
# change makefile to have GPU and OPENCV enabled
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# Out:
# /content/darknet

# %%
# verify CUDA
# !/usr/local/cuda/bin/nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Wed_Jul_22_19:09:09_PDT_2020
# Cuda compilation tools, release 11.0, V11.0.221
# Build cuda_11.0_bu.TC445_37.28845127_0

# %%
# make darknet (build)
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
# ...

# %%
# %cd ..
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# /content
# Mounted at /content/gdrive

# %%
# copy the .zip file into the root directory of cloud VM
# !cp /content/gdrive/MyDrive/yolov3_tiny/data.zip /content

# %%
# unzip the zip file and its contents should now be in /darknet/data/obj
# !unzip /content/gdrive/MyDrive/yolo-6-8/dataMoi.zip -d /content/darknet/data
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/darknet/data/dataMoi/right (543).png
#   inflating: /content/darknet/data/dataMoi/right (543).txt
#   inflating: /content/darknet/data/dataMoi/right (544).png
#   inflating: /content/darknet/data/dataMoi/right (544).txt
#   inflating: /content/darknet/data/dataMoi/right (545).png
#   inflating: /content/darknet/data/dataMoi/right (545).txt
#   inflating: /content/darknet/data/dataMoi/right (546).png
#   inflating: /content/darknet/data/dataMoi/right (546).txt
#   inflating: /content/darknet/data/dataMoi/right (547).png
#   inflating: /content/darknet/data/dataMoi/right (547).txt
#   inflating: /content/darknet/data/dataMoi/right (548).png
#   inflating: /content/darknet/data/dataMoi/right (548).txt
#   inflating: /content/darknet/data/dataMoi/right (549).png
#   inflating: /content/darknet/data/dataMoi/right (549).txt
#   inflating: /content/darknet/data/dataMoi/right (55).png
# ...

# %%
# upload the custom .cfg back to cloud VM from Google Drive
# !cp /content/gdrive/MyDrive/yolov3_tiny/yolov3-tiny_costom.cfg /content/darknet/cfg

# %%
# !cp /content/gdrive/MyDrive/yolo-tiny-v3-17-6/obj.names /content/darknet/data
# !cp /content/gdrive/MyDrive/yolo-tiny-v3-17-6/obj.data  /content/darknet/data

# %%
# !cp /content/gdrive/MyDrive/yolov3_tiny/generate_train.py /content/darknet/data

# %%
# !cp /content/gdrive/MyDrive/yolov3_tiny/train.txt /content/darknet/data/

# %%
# upload pretrained convolutional layer weights
# !cd /content/darknet
# !wget http://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2021-08-06 08:20:35--  http://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://pjreddie.com/media/files/darknet53.conv.74 [following]
# --2021-08-06 08:20:35--  https://pjreddie.com/media/files/darknet53.conv.74
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  63.6MB/s    in 2.4s
#
# 2021-08-06 08:20:38 (63.6 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %%
14
# !cp /content/darknet53.conv.74 /content/darknet

# %%
# !./darknet/darknet detector train /content/darknet/data/obj.data /content/darknet/cfg/yolov3-tiny.cfg /content/darknet/darknet53.conv.74 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#  total_bbox = 468483, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.848175), count: 28, class_loss = 0.209134, iou_loss = 0.082342, total_loss = 0.291476
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.868745), count: 4, class_loss = 0.000444, iou_loss = 0.008975, total_loss = 0.009419
#  total_bbox = 468515, rewritten_bbox = 0.000000 %
#
#  7475: 0.111813, 0.102788 avg loss, 0.000010 rate, 1.123549 seconds, 478400 images, 0.146981 hours left
# Loaded: 0.000041 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.852390), count: 24, class_loss = 0.007551, iou_loss = 0.042654, total_loss = 0.050204
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.833976), count: 8, class_loss = 0.003397, iou_loss = 0.016453, total_loss = 0.019849
# ...
